# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaunak-Mukherjee/Nequip-reimplement-Toluene/blob/main/Main_full_nequip_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive (if not already mounted)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri May  9 20:28:24 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             44W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Import libraries
# !pip install equinox
import numpy as np
import pandas as pd
from pathlib import Path
import yaml
from tabulate import tabulate
import csv
import jax.numpy as jnp
import equinox as eqx
from jax.scipy.special import sph_harm
import numpy as np
import jax.numpy as jnp
from scipy.spatial import cKDTree
from typing import Dict
import matplotlib.pyplot as plt
import os
import numpy as np
from pathlib import Path
import pandas as pd
import numpy as np
import os
import jax
import jax.numpy as jnp
import optax
from functools import partial
from typing import Sequence
import time
from tqdm.notebook import tqdm
# Out:
# Collecting equinox
#   Downloading equinox-0.12.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: jax>=0.4.38 in /usr/local/lib/python3.11/dist-packages (from equinox) (0.5.2)
# Collecting jaxtyping>=0.2.20 (from equinox)
#   Downloading jaxtyping-0.3.2-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from equinox) (4.13.2)
# Collecting wadler-lindig>=0.1.0 (from equinox)
#   Downloading wadler_lindig-0.1.5-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: jaxlib<=0.5.2,>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.38->equinox) (0.5.1)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.38->equinox) (0.4.1)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.38->equinox) (2.0.2)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.38->equinox) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.38->equinox) (1.15.2)
# Downloading equinox-0.12.1-py3-none-any.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 kB 15.0 MB/s eta 0:00:00
# Downloading jaxtyping-0.3.2-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 4.7 MB/s eta 0:00:00
# Downloading wadler_lindig-0.1.5-py3-none-any.whl (20 kB)
# Installing collected packages: wadler-lindig, jaxtyping, equinox
# Successfully installed equinox-0.12.1 jaxtyping-0.3.2 wadler-lindig-0.1.5

# %%
import os
# Define the target directory in Google Drive
target_dir = '/content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/benchmark_data/'

# Create the target directory if it doesn't exist (within Google Drive)
os.makedirs(target_dir, exist_ok=True)

yaml_file_path = '/content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/configs/custom.yaml'

try:
    with open(yaml_file_path, 'r') as f:
        config = yaml.safe_load(f)
        dataset_url = config.get('dataset_url')

        if dataset_url:
            # Download the zip file using the URL from the YAML
            # !wget "{dataset_url}" -O "{target_dir}toluene.zip"

            # Unzip the file
            # !unzip -o "{target_dir}toluene.zip" -d "{target_dir}"
        else:
            print("Error: 'dataset_url' not found in the YAML configuration.")

except FileNotFoundError:
    print(f"Error: YAML file '{yaml_file_path}' not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# --2025-05-09 20:28:42--  http://quantum-machine.org/gdml/data/npz/md17_toluene.npz
# Resolving quantum-machine.org (quantum-machine.org)... 130.149.80.145
# Connecting to quantum-machine.org (quantum-machine.org)|130.149.80.145|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 303150886 (289M)
# Saving to: ‘/content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/benchmark_data/toluene.zip’
#
# /content/drive/MyDr 100%[===================>] 289.11M  19.6MB/s    in 17s
#
# 2025-05-09 20:29:00 (16.6 MB/s) - ‘/content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/benchmark_data/toluene.zip’ saved [303150886/303150886]
#
# Archive:  /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/benchmark_data/toluene.zip
#   inflating: /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/benchmark_data/E.npy
#   inflating: /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/benchmark_data/name.npy
#   inflating: /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/benchmark_data/F.npy
#   inflating: /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/benchmark_data/theory.npy
#   inflating: /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/benchmark_data/R.npy
#   inflating: /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/benchmark_data/z.npy
#   inflating: /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/benchmark_data/type.npy
#   inflating: /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/benchmark_data/md5.npy

# %%
# Flatten nested dictionaries
def flatten_dict(d, parent_key='', sep='.'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# Load and flatten the YAML config
with open(yaml_file_path, 'r') as file:
    config = yaml.load(file, Loader=yaml.FullLoader)

flat_config = flatten_dict(config)

# Convert to tabular format
table_data = list(flat_config.items())
print(tabulate(table_data, headers=["Parameter", "Value"], tablefmt=None))
# Out:
# Parameter                                    Value
# -------------------------------------------  -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# root                                         results/toluene
# run_name                                     example-run-toluene
# seed                                         123
# dataset_seed                                 456
# append                                       True
# default_dtype                                float64
# model_dtype                                  float32
# allow_tf32                                   True
# model_builders                               ['SimpleIrrepsConfig', 'EnergyModel', 'PerSpeciesRescale', 'ForceOutput', 'RescaleEnergyEtc']
# r_max                                        5.0
# num_layers                                   6
# l_max                                        3
# parity                                       True
# num_features                                 64
# nonlinearity_type                            gate
# resnet                                       False
# nonlinearity_scalars.e                       silu
# nonlinearity_scalars.o                       tanh
# nonlinearity_gates.e                         silu
# nonlinearity_gates.o                         tanh
# num_basis                                    16
# BesselBasis_trainable                        True
# PolynomialCutoff_p                           6
# invariant_layers                             2
# invariant_neurons                            64
# avg_num_neighbors                            auto
# use_sc                                       True
# dataset                                      npz
# dataset_url                                  http://quantum-machine.org/gdml/data/npz/md17_toluene.npz
# dataset_file_name                            ./benchmark_data/md17_toluene.npz
# key_mapping.z                                atomic_numbers
# key_mapping.E                                total_energy
# key_mapping.F                                forces
# key_mapping.R                                pos
# npz_fixed_field_keys                         ['atomic_numbers']
# chemical_symbols                             ['H', 'C']
# wandb                                        True
# wandb_project                                toluene-example
# wandb_watch                                  False
# verbose                                      info
# log_batch_freq                               100
# log_epoch_freq                               1
# save_checkpoint_freq                         -1
# save_ema_checkpoint_freq                     -1
# n_train                                      950
# n_val                                        50
# learning_rate                                0.0005
# batch_size                                   5
# validation_batch_size                        10
# max_epochs                                   100000
# train_val_split                              random
# shuffle                                      True
# metrics_key                                  validation_loss
# use_ema                                      True
# ema_decay                                    0.99
# ema_use_num_updates                          True
# report_init_validation                       True
# early_stopping_patiences.validation_loss     50
# early_stopping_delta.validation_loss         0.005
# early_stopping_cumulative_delta              False
# early_stopping_lower_bounds.LR               1e-05
# early_stopping_upper_bounds.cumulative_wall  1e+100
# loss_coeffs.forces                           1.0
# loss_coeffs.total_energy                     [1.0, 'PerAtomMSELoss']
# metrics_components                           [['forces', 'mae'], ['forces', 'rmse'], ['forces', 'mae', {'PerSpecies': True, 'report_per_component': False}], ['forces', 'rmse', {'PerSpecies': True, 'report_per_component': False}], ['total_energy', 'mae'], ['total_energy', 'mae', {'PerAtom': True}]]
# optimizer_name                               AdamW
# optimizer_amsgrad                            True
# optimizer_betas                              [0.9, 0.999]
# optimizer_eps                                1e-08
# optimizer_weight_decay                       1e-4
# max_gradient_norm
# lr_scheduler_name                            ReduceLROnPlateau
# lr_scheduler_patience                        50
# lr_scheduler_factor                          0.5
# per_species_rescale_scales_trainable         False
# per_species_rescale_shifts_trainable         False
# per_species_rescale_shifts                   dataset_per_atom_total_energy_mean
# per_species_rescale_scales
# global_rescale_shift
# global_rescale_scale                         dataset_forces_rms
# global_rescale_shift_trainable               False
# global_rescale_scale_trainable               False

# %% [markdown]
# Load and Process the NPZ File Using Dataset Logic. Load 1000 frames.

# %%
import numpy as np
import pandas as pd
from pathlib import Path


# Load the full MD‑17 toluene NPZ

orig_path = Path("/content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/benchmark_data/toluene.zip")
data      = np.load(orig_path, allow_pickle=True)
print("Full dataset keys:", list(data.keys()))
print("Original frame count:", data['E'].shape[0])


# Slice down to MAX_FRAMES and save a smaller NPZ

MAX_FRAMES = 1000
n_frames   = data['E'].shape[0]

# Build a sliced dict
sliced = {}
for k, v in data.items():
    # Only slice per-frame arrays of shape (n_frames, ...)
    if isinstance(v, np.ndarray) and v.ndim >= 1 and v.shape[0] == n_frames:
        sliced[k] = v[:MAX_FRAMES]
    else:
        sliced[k] = v

# Report new shapes
print("Sliced dataset shapes:")
for k, v in sliced.items():
    if isinstance(v, np.ndarray):
        print(f"  {k}: {v.shape}")

# Save out the subset NPZ
npz_path = orig_path.parent / "md17_toluene_1000.npz"
np.savez(npz_path, **sliced)
print(f"Saved subset NPZ to {npz_path}")


# Rebuild per-atom records over only those 1000 frames

num_frames = sliced['E'].shape[0]    # == 1000
num_atoms  = sliced['R'].shape[1]    # e.g. 15

atom_props    = ['R', 'F']
atom_scalars  = ['z']
global_props  = [k for k in sliced if k not in atom_props + atom_scalars]

records = []
for frame_idx in range(num_frames):
    # collect global fields for this frame
    frame_data = {}
    for key in global_props:
        val = sliced[key]
        # if it's an array with a frame dimension, index it; else just copy
        frame_data[key] = val[frame_idx] if (isinstance(val, np.ndarray) and val.ndim > 0) else val

    R_frame = sliced['R'][frame_idx]   # shape (num_atoms, 3)
    F_frame = sliced['F'][frame_idx]   # shape (num_atoms, 3)
    z_vals  = sliced['z']              # shape (num_atoms,)

    for atom_idx in range(num_atoms):
        rec = {
            "frame":         frame_idx,
            "atom_index":    atom_idx,
            **frame_data,
            "x":              R_frame[atom_idx, 0],
            "y":              R_frame[atom_idx, 1],
            "z":              R_frame[atom_idx, 2],
            "fx":             F_frame[atom_idx, 0],
            "fy":             F_frame[atom_idx, 1],
            "fz":             F_frame[atom_idx, 2],
            "atomic_number":  int(z_vals[atom_idx]),
        }
        records.append(rec)

# For plotting and inspection
df = pd.DataFrame.from_records(records)
print("Frame count of dataset used here:", len(df['frame'].unique()))
# Out:
# Full dataset keys: ['E', 'name', 'F', 'theory', 'R', 'z', 'type', 'md5']
# Original frame count: 442790
# Sliced dataset shapes:
#   E: (1000, 1)
#   name: ()
#   F: (1000, 15, 3)
#   theory: ()
#   R: (1000, 15, 3)
#   z: (15,)
#   type: ()
#   md5: ()
# Saved subset NPZ to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/benchmark_data/md17_toluene_1000.npz
# Frame count of dataset used here: 1000

# %%
# Visualize 3D structure of the molecule at a specific frame
def plot_molecular_structure(df, frame_idx=0):
    # Filter data for the specific frame
    frame_data = df[df['frame'] == frame_idx]

    # Create an atomic number to element name and color mapping
    element_map = {1: 'H', 6: 'C', 7: 'N', 8: 'O'}
    color_map = {1: 'lightgray', 6: 'black', 7: 'blue', 8: 'red'}
    size_map = {1: 80, 6: 200, 7: 200, 8: 200}

    # Create 3D plot
    fig = plt.figure(figsize=(8, 5))
    ax = fig.add_subplot(111, projection='3d')

    # Plot atoms
    for _, atom in frame_data.iterrows():
        atomic_num = atom['atomic_number']
        element = element_map.get(atomic_num, 'X')
        color = color_map.get(atomic_num, 'gray')
        size = size_map.get(atomic_num, 100)

        ax.scatter(
            atom['x'], atom['y'], atom['z'],
            color=color, s=size, edgecolors='black',
            label=f"{element}" if element not in [l.get_label() for l in ax.get_lines()] else ""
        )

    # Draw bonds (simplified approach - connect atoms that are close)
    positions = frame_data[['x', 'y', 'z']].values
    for i in range(len(positions)):
        for j in range(i+1, len(positions)):
            # Calculate distance between atoms
            dist = np.sqrt(np.sum((positions[i] - positions[j])**2))
            # If atoms are close enough, draw a bond
            if dist < 1.7:  # Typical bond length threshold in Angstroms
                ax.plot(
                    [positions[i, 0], positions[j, 0]],
                    [positions[i, 1], positions[j, 1]],
                    [positions[i, 2], positions[j, 2]],
                    'k-', linewidth=1, alpha=0.6
                )

    # Remove duplicate labels
    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    plt.legend(by_label.values(), by_label.keys(), loc='best')

    # Set labels and title
    ax.set_xlabel('X (Å)')
    ax.set_ylabel('Y (Å)')
    ax.set_zlabel('Z (Å)')
    ax.set_title(f'Toluene Molecular Structure - Frame {frame_idx}')

    # Adjust view angle for better visualization
    ax.view_init(elev=30, azim=45)
    plt.tight_layout()
    plt.show()


# Plot molecular structure at frame 999
plot_molecular_structure(df, frame_idx=999)

# %%
class NequIPDatasetJAX:
    def __init__(self, npz_path: str, r_max: float, max_neighbors: int = 32):
        """
        Args:
            npz_path: Path to .npz file with keys 'R', 'F', 'E', 'z'.
            r_max: cutoff radius for neighbor search.
            max_neighbors: maximum number of neighbors per atom.
        """
        data = np.load(npz_path, allow_pickle=True)
        self.R = data['R']  # (n_frames, n_atoms, 3)
        self.F = data['F']  # (n_frames, n_atoms, 3)
        self.E = data['E']  # (n_frames,)
        self.Z = data['z']  # (n_atoms,)

        self.n_frames, self.n_atoms, _ = self.R.shape
        self.r_max = r_max
        self.max_neighbors = max_neighbors

        # Precompute neighbor lists
        self.neighbor_idx = np.zeros((self.n_frames, self.n_atoms, max_neighbors), dtype=np.int32)
        self.neighbor_mask = np.zeros((self.n_frames, self.n_atoms, max_neighbors), dtype=bool)
        self.neighbor_dist = np.zeros((self.n_frames, self.n_atoms, max_neighbors), dtype=np.float32)
        for t in range(self.n_frames):
            pos = self.R[t]
            tree = cKDTree(pos)
            all_nbrs = tree.query_ball_tree(tree, self.r_max)
            for i, nbrs in enumerate(all_nbrs):
                # remove self
                nbrs = [j for j in nbrs if j != i]
                # sort by distance
                dists = np.linalg.norm(pos[nbrs] - pos[i], axis=1)
                sorted_idx = np.argsort(dists)
                nbrs = [nbrs[k] for k in sorted_idx][:max_neighbors]
                # fill arrays
                k = len(nbrs)
                self.neighbor_idx[t, i, :k] = nbrs
                self.neighbor_mask[t, i, :k] = True
                self.neighbor_dist[t, i, :k] = dists[sorted_idx[:k]]

    def __len__(self) -> int:
        return self.n_frames

    def get(self, idx: int) -> Dict[str, jnp.ndarray]:
        """
        Get single graph as JAX arrays.
        """
        pos    = jnp.array(self.R[idx])            # (n_atoms,3)
        forces = jnp.array(self.F[idx])            # (n_atoms,3)
        energy = jnp.array(self.E[idx])            # ()
        z      = jnp.array(self.Z)                 # (n_atoms,)
        nbr_idx = jnp.array(self.neighbor_idx[idx])# (n_atoms,max_neighbors)
        nbr_dist= jnp.array(self.neighbor_dist[idx])# (n_atoms,max_neighbors)
        mask    = jnp.array(self.neighbor_mask[idx])# (n_atoms,max_neighbors)
        return {
            'pos': pos,
            'z': z,
            'nbr_idx': nbr_idx,
            'nbr_dist': nbr_dist,
            'nbr_mask': mask,
            'energy': energy,
            'forces': forces
        }

    def get_batch(self, indices: np.ndarray) -> Dict[str, jnp.ndarray]:
        """
        Batch multiple graphs (assuming same number of nodes per graph).
        """
        batch = {k: jnp.stack([self.get(i)[k] for i in indices]) for k in self.get(indices[0])}
        return batch

# %%
# Parse cutoff and neighbor count from flat_config
r_max_value = flat_config['r_max']
r_max = float(r_max_value)

avg_nbr = flat_config.get('avg_num_neighbors', 'auto')
if isinstance(avg_nbr, (int, float)):
    max_neighbors = int(avg_nbr)
elif isinstance(avg_nbr, str) and avg_nbr.lower() == 'auto':
    max_neighbors = 32
else:
    max_neighbors = int(avg_nbr)

print("Using r_max =", r_max, "and max_neighbors =", max_neighbors)
# Out:
# Using r_max = 5.0 and max_neighbors = 32

# %%
npz_path
# Out:
# PosixPath('/content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/benchmark_data/md17_toluene_1000.npz')

# %%
# Now initialize and test
ds = NequIPDatasetJAX(
    npz_path,
    r_max=r_max,
    max_neighbors=max_neighbors
)
sample = ds.get(0)
print({k: v.shape for k, v in sample.items()})
# Out:
# {'pos': (15, 3), 'z': (15,), 'nbr_idx': (15, 32), 'nbr_dist': (15, 32), 'nbr_mask': (15, 32), 'energy': (1,), 'forces': (15, 3)}

# %%
class RealSphericalHarmonics(eqx.Module):
    """
    Manual real spherical harmonics for l_max up to 3.
    Produces components in the order:
      ℓ=0:  Y₀⁰
      ℓ=1:  Y₁⁻¹, Y₁⁰, Y₁¹
      ℓ=2:  Y₂⁻², Y₂⁻¹, Y₂⁰, Y₂¹, Y₂²
      ℓ=3:  Y₃⁻³, Y₃⁻², Y₃⁻¹, Y₃⁰, Y₃¹, Y₃², Y₃³
    """
    l_max: int
    num_harmonics: int

    def __init__(self, l_max: int):
        assert 0 <= l_max <= 3, "Supports l_max ∈ {0,1,2,3}"
        # 1 + 3 + 5 + 7 = 16 when l_max=3
        num = 1 + (3 if l_max >= 1 else 0) \
                + (5 if l_max >= 2 else 0) \
                + (7 if l_max >= 3 else 0)
        self.l_max = l_max
        self.num_harmonics = num
        super().__init__()

    def __call__(self, vecs: jnp.ndarray) -> jnp.ndarray:
        x, y, z = vecs[...,0], vecs[...,1], vecs[...,2]
        # add a tiny floor so we never divide by zero
        eps = 1e-12
        r2 = x*x + y*y + z*z + eps
        r  = jnp.sqrt(r2)
        r2 = r*r
        r3 = r2*r

        out = []
        # ℓ=0
        out.append(
            jax.lax.cond(
                self.l_max >= 0,
                lambda _: 0.5 * jnp.sqrt(1/jnp.pi) * jnp.ones_like(r),
                lambda _: jnp.zeros_like(r),
                operand=None
            )
        )
        # ℓ=1
        out.extend(
            jax.lax.cond(
                self.l_max >= 1,
                lambda _: [
                    jnp.sqrt(3/(4*jnp.pi))*(y/r),
                    jnp.sqrt(3/(4*jnp.pi))*(z/r),
                    jnp.sqrt(3/(4*jnp.pi))*(x/r),
                ],
                lambda _: [jnp.zeros_like(r)]*3,
                operand=None
            )
        )
        # ℓ=2
        out.extend(
            jax.lax.cond(
                self.l_max >= 2,
                lambda _: [
                    jnp.sqrt(15/(4*jnp.pi))*(x*y)/r2,
                    jnp.sqrt(15/(4*jnp.pi))*(y*z)/r2,
                    0.25*jnp.sqrt(5/jnp.pi)*(2*z*z - x*x - y*y)/r2,
                    jnp.sqrt(15/(4*jnp.pi))*(x*z)/r2,
                    0.5*jnp.sqrt(15/jnp.pi)*((x*x - y*y))/r2,
                ],
                lambda _: [jnp.zeros_like(r)]*5,
                operand=None
            )
        )
        # ℓ=3
        out.extend(
            jax.lax.cond(
                self.l_max >= 3,
                lambda _: [
                    jnp.sqrt(35/(16*jnp.pi)) * ((3*x*x - y*y)*y)    / r3,  # Y₃⁻³
                    jnp.sqrt(105/(4*jnp.pi)) * (x*y*z)               / r3,  # Y₃⁻²
                    jnp.sqrt(21/(8*jnp.pi)) * (y*(4*z*z - x*x - y*y))/ r3,  # Y₃⁻¹
                    jnp.sqrt(7/(4*jnp.pi))  * (z*(2*z*z - 3*x*x - 3*y*y))/ r3,  # Y₃⁰
                    jnp.sqrt(21/(8*jnp.pi)) * (x*(4*z*z - x*x - y*y)) / r3,  # Y₃¹
                    jnp.sqrt(105/(4*jnp.pi)) * ((x*x - y*y)*z)       / r3,  # Y₃²
                    jnp.sqrt(35/(16*jnp.pi)) * (x*(x*x - 3*y*y))      / r3,  # Y₃³
                ],
                lambda _: [jnp.zeros_like(r)]*7,
                operand=None
            )
        )
        return jnp.stack(out, axis=-1)

# %%
# Test code
dirs = jnp.stack([
    jnp.array([1.0,0.0,0.0]),    # +x̂
    jnp.array([0.0,1.0,0.0]),    # +ŷ
    jnp.array([0.0,0.0,1.0]),    # +ẑ
    jnp.array([1.0,1.0,1.0]) / jnp.sqrt(3),
], axis=0)

sh = RealSphericalHarmonics(l_max=3)
Y = sh(dirs)

# Print and eyeball
print("Y(+x):", Y[0])
print("Y(+y):", Y[1])
print("Y(+z):", Y[2])
print("Y(diag):", Y[3])
# Out:
# Y(+x): [ 0.28209478  0.          0.          0.48860252  0.          0.
#  -0.31539157  0.          1.0925484   0.          0.         -0.
#  -0.         -0.9140916   0.          0.8344477 ]
# Y(+y): [ 0.28209478  0.48860252  0.          0.          0.          0.
#  -0.31539157  0.         -1.0925484  -0.8344477   0.         -0.9140916
#  -0.         -0.         -0.         -0.        ]
# Y(+z): [0.28209478 0.         0.48860252 0.         0.         0.
#  0.63078314 0.         0.         0.         0.         0.
#  1.4927053  0.         0.         0.        ]
# Y(diag): [ 0.28209478  0.2820948   0.2820948   0.2820948   0.3641828   0.3641828
#   0.          0.3641828   0.          0.32117912  0.5562985   0.3518341
#  -0.57454264  0.3518341   0.         -0.32117912]

# %%
class GaussianSmearing(eqx.Module):
    """
    Expands scalar distances into Gaussian radial basis functions.
    """
    centers: jnp.ndarray
    widths:  jnp.ndarray

    def __init__(self, start: float, stop: float, num_basis: int):
        # compute centers and widths
        centers = jnp.linspace(start, stop, num_basis)
        widths  = jnp.full((num_basis,), (stop - start) / (num_basis - 1))
        # assign as plain attributes
        self.centers = centers
        self.widths  = widths
        # register with Equinox
        super().__init__()

    def __call__(self, distances: jnp.ndarray) -> jnp.ndarray:
        d = jnp.expand_dims(distances, axis=-1)
        diff = d - self.centers
        return jnp.exp(-0.5 * (diff / self.widths) ** 2)

# %%
# Test block
gs = GaussianSmearing(start=0.0, stop=3.0, num_basis=5)

distances_1d = jnp.array([0.0, 1.5, 3.0])  # shape (3,)
output_1d = gs(distances_1d)

distances_2d = jnp.array([[0.0, 1.0], [2.0, 3.0]])  # shape (2,2)
output_2d = gs(distances_2d)

print("Centers:", gs.centers)
print("Widths: ", gs.widths)
print("\nInput distances (1D):", distances_1d)
print("Output (1D) shape:", output_1d.shape)
print(output_1d)

print("\nInput distances (2D):")
print(distances_2d)
print("Output (2D) shape:", output_2d.shape)
print(output_2d)
# Out:
# Centers: [0.   0.75 1.5  2.25 3.  ]
# Widths:  [0.75 0.75 0.75 0.75 0.75]
#
# Input distances (1D): [0.  1.5 3. ]
# Output (1D) shape: (3, 5)
# [[1.0000000e+00 6.0653067e-01 1.3533528e-01 1.1108997e-02 3.3546262e-04]
#  [1.3533528e-01 6.0653067e-01 1.0000000e+00 6.0653067e-01 1.3533528e-01]
#  [3.3546262e-04 1.1108997e-02 1.3533528e-01 6.0653067e-01 1.0000000e+00]]
#
# Input distances (2D):
# [[0. 1.]
#  [2. 3.]]
# Output (2D) shape: (2, 2, 5)
# [[[1.0000000e+00 6.0653067e-01 1.3533528e-01 1.1108997e-02 3.3546262e-04]
#   [4.1111228e-01 9.4595945e-01 8.0073738e-01 2.4935217e-01 2.8565494e-02]]
#
#  [[2.8565494e-02 2.4935217e-01 8.0073738e-01 9.4595945e-01 4.1111228e-01]
#   [3.3546262e-04 1.1108997e-02 1.3533528e-01 6.0653067e-01 1.0000000e+00]]]

# %%
class EquivariantConv(eqx.Module):
    """
    Equivariant message-passing convolution block.
    """
    radial_fn: eqx.Module    # GaussianSmearing
    sph_fn:    eqx.Module    # RealSphericalHarmonics
    W:         jnp.ndarray   # weights of shape (B, H, in_feats, out_feats)

    def __init__(
        self,
        rbf: eqx.Module,
        sph: eqx.Module,
        in_feats: int,
        out_feats: int,
        key: jax.random.PRNGKey = None
    ):
        # store sub-modules
        self.radial_fn = rbf
        self.sph_fn    = sph
        # initialize weight tensor
        B = rbf.centers.shape[0]
        H = sph.num_harmonics
        rng = jax.random.PRNGKey(0) if key is None else key
        scale = 1.0 / jnp.sqrt(in_feats * B * H)
        self.W = jax.random.normal(rng, (B, H, in_feats, out_feats)) * scale
        # register fields
        super().__init__()

    def __call__(
        self,
        feats:     jnp.ndarray,   # (n_atoms, in_feats)
        pos:       jnp.ndarray,   # (n_atoms, 3)
        nbr_idx:   jnp.ndarray,   # (n_atoms, n_nbr)
        nbr_dist:  jnp.ndarray,   # (n_atoms, n_nbr)
        nbr_mask:  jnp.ndarray    # (n_atoms, n_nbr) boolean
    ) -> jnp.ndarray:
        # gather neighbor positions
        nbr_pos   = pos[nbr_idx]               # (n_atoms, n_nbr, 3)
        vecs      = nbr_pos - pos[:, None, :]  # (n_atoms, n_nbr, 3)
        # compute radial and angular features
        phi       = self.radial_fn(nbr_dist)   # (n_atoms, n_nbr, B)
        Y         = self.sph_fn(vecs)          # (n_atoms, n_nbr, H)
        # neighbor features and mask
        nbr_feats = feats[nbr_idx]             # (n_atoms, n_nbr, in_feats)
        mask      = nbr_mask[..., None]        # (n_atoms, n_nbr, 1)

        # zero out invalid neighbors
        phi       *= mask
        Y         *= mask
        nbr_feats *= mask

        # message: sum over b,h,i  phi * Y * W * h_j
        msgs = jnp.einsum('anb,anh,bhio,ani->ano', phi, Y, self.W, nbr_feats)
        # aggregate
        return jnp.sum(msgs, axis=1)           # (n_atoms, out_feats)

# %%
# Test Block
r_max     = float(flat_config['r_max'])
num_basis = int(flat_config['num_basis'])
l_max     = int(flat_config['l_max'])
hidden    = int(flat_config['num_features'])

rbf = GaussianSmearing(0.0, r_max, num_basis)
sh  = RealSphericalHarmonics(l_max=l_max)

key = jax.random.PRNGKey(123)
conv = EquivariantConv(rbf, sh, in_feats=hidden, out_feats=hidden, key=key)

# Grab one sample
sample = ds.get(0)
pos     = sample['pos']      # (n_atoms, 3)
nbr_idx = sample['nbr_idx']  # (n_atoms, n_nbr)
nbr_dist= sample['nbr_dist'] # (n_atoms, n_nbr)
nbr_mask= sample['nbr_mask'] # (n_atoms, n_nbr)

# Create a dummy feature matrix
h0 = jnp.ones((pos.shape[0], hidden), dtype=jnp.float32)

# Forward through conv
h1 = conv(h0, pos, nbr_idx, nbr_dist, nbr_mask)

print("Input feats shape:", h0.shape)
print("Output feats shape:", h1.shape)
print("Any NaNs in output?", jnp.isnan(h1).any())
# Out:
# Input feats shape: (15, 64)
# Output feats shape: (15, 64)
# Any NaNs in output? False

# %%
# Define Nequip Model
class NequIPModel(eqx.Module):
    """
    NequIP model.
    """
    embedding: jnp.ndarray
    convs:     Sequence
    w1:        jnp.ndarray
    b1:        jnp.ndarray
    w2:        jnp.ndarray
    b2:        jnp.ndarray

    def __init__(self, max_z, hidden_feats, r_max, num_basis, l_max, num_layers, key):
        keys = jax.random.split(key, 3 + num_layers)
        self.embedding = (jax.random.normal(keys[0], (max_z+1, hidden_feats))
                          * jnp.sqrt(1.0/hidden_feats))
        # shared RBF/SH
        rbf = GaussianSmearing(0.0, r_max, num_basis)
        sh  = RealSphericalHarmonics(l_max=l_max)
        # conv stack
        convs = [EquivariantConv(rbf, sh,
                                 hidden_feats, hidden_feats,
                                 key=keys[1+i])
                 for i in range(num_layers)]
        self.convs = tuple(convs)
        # manual readout
        k1, k2, _ = keys[-3], keys[-2], keys[-1]
        scale = jnp.sqrt(1.0/hidden_feats)
        self.w1 = jax.random.normal(k1, (hidden_feats, hidden_feats)) * scale
        self.b1 = jnp.zeros((hidden_feats,))
        self.w2 = jax.random.normal(k2, (hidden_feats, 1)) * scale
        self.b2 = jnp.array([mean_E_pa])
        super().__init__()

    def __call__(self, pos, z, nbr_idx, nbr_dist, nbr_mask):
        h = self.embedding[z]
        for conv in self.convs:
            h = jax.nn.silu(conv(h, pos, nbr_idx, nbr_dist, nbr_mask))
        h_read = jax.nn.silu(jnp.matmul(h, self.w1) + self.b1)
        e_i    = (jnp.matmul(h_read, self.w2) + self.b2).squeeze(-1)
        return jnp.sum(e_i)

    def forces(self, pos, z, nbr_idx, nbr_dist, nbr_mask):
        energy_fn = lambda p: self(p, z, nbr_idx, nbr_dist, nbr_mask)
        return -jax.grad(energy_fn)(pos)

# %%
class EquivariantConv(eqx.Module):
    """
    Equivariant message-passing convolution block.
    """
    radial_fn: eqx.Module      # GaussianSmearing
    sph_fn:    eqx.Module      # RealSphericalHarmonics
    W:         jnp.ndarray     # weights of shape (B, H, in_feats, out_feats)

    def __init__(
        self,
        rbf: eqx.Module,
        sph: eqx.Module,
        in_feats: int,
        out_feats: int,
        key=None
    ):
        # assign submodules
        self.radial_fn = rbf
        self.sph_fn    = sph
        # weight init
        B = rbf.centers.shape[0]
        H = sph.num_harmonics
        rng = jax.random.PRNGKey(0) if key is None else key
        scale = 1.0 / jnp.sqrt(in_feats * B * H)
        self.W = jax.random.normal(rng, (B, H, in_feats, out_feats)) * scale
        super().__init__()

    def __call__(
        self,
        feats: jnp.ndarray,       # (n_atoms, in_feats)
        pos:   jnp.ndarray,       # (n_atoms, 3)
        nbr_idx:  jnp.ndarray,    # (n_atoms, n_nbr)
        nbr_dist: jnp.ndarray,    # (n_atoms, n_nbr)
        nbr_mask: jnp.ndarray     # (n_atoms, n_nbr) boolean
    ) -> jnp.ndarray:
        # gather neighbor data
        nbr_pos = pos[nbr_idx]               # (n_atoms, n_nbr, 3)
        vecs = nbr_pos - pos[:, None, :]  # (n_atoms, n_nbr, 3)
        phi = self.radial_fn(nbr_dist)   # (n_atoms, n_nbr, B)
        Y = self.sph_fn(vecs)          # (n_atoms, n_nbr, H)
        nbr_feats = feats[nbr_idx]             # (n_atoms, nbr, in_feats)
        mask = nbr_mask[..., None]        # (n_atoms, n_nbr, 1)

        # apply mask
        phi = phi       * mask
        Y = Y         * mask
        nbr_feats = nbr_feats * mask

        # compute messages: sum over b,h,i  phi * Y * W * h_j
        msgs = jnp.einsum('anb,anh,bhio,ani->ano', phi, Y, self.W, nbr_feats)
        return jnp.sum(msgs, axis=1)           # (n_atoms, out_feats)

# %%
# Recompute hyperparameters
max_z     = int(jnp.max(ds.Z))
hidden    = int(flat_config['num_features'])
r_max     = float(flat_config['r_max'])
num_basis = int(flat_config['num_basis'])
l_max     = int(flat_config['l_max'])
n_layers  = int(flat_config['num_layers'])
seed      = int(flat_config['seed'])
key       = jax.random.PRNGKey(seed)
learning_rate = float(flat_config['learning_rate'])
force_coeff   = float(flat_config['loss_coeffs.forces'])
batch_size    = int(flat_config['batch_size'])
num_epochs    = int(flat_config['max_epochs'])

print(f"max_z {max_z}")
print(f"hidden {hidden}")
print(f"r_max {r_max}")
print(f"num_basis {num_basis}")
print(f"l_max {l_max}")
print(f"n_layers {n_layers}")
print(f"seed {seed}")
print(f"learning_rate {learning_rate}")
print(f"force_coeff {force_coeff}")
print(f"batch_size {batch_size}")
print(f"num_epochs {num_epochs}")
# Out:
# max_z 6
# hidden 64
# r_max 5.0
# num_basis 16
# l_max 3
# n_layers 6
# seed 123
# learning_rate 0.0005
# force_coeff 1.0
# batch_size 5
# num_epochs 100000

# %%
# Number of atoms per frame
n_atoms = ds.R.shape[1]

# Gather per‑atom energies for every frame
E_pa = []
for i in range(len(ds)):
    info = ds.get(i)
    E_pa.append(np.array(info['energy']) / n_atoms)
E_pa = np.stack(E_pa)          # shape (n_frames,)

mean_E_pa = float(E_pa.mean())
std_E_pa  = float(E_pa.std())
print(f"Dataset per‑atom energy: mean = {mean_E_pa:.4f}, std = {std_E_pa:.4f}")
# Out:
# Dataset per‑atom energy: mean = -11348.2256, std = 0.3892

# %%
# instantiate Model Arch
model = NequIPModel(max_z, hidden, r_max, num_basis, l_max, n_layers, key)
model
# Out:
# NequIPModel(
#   embedding=f32[7,64],
#   convs=(
#     EquivariantConv(
#       radial_fn=GaussianSmearing(centers=f32[16], widths=weak_f32[16]),
#       sph_fn=RealSphericalHarmonics(l_max=3, num_harmonics=16),
#       W=f32[16,16,64,64]
#     ),
#     EquivariantConv(
#       radial_fn=GaussianSmearing(centers=f32[16], widths=weak_f32[16]),
#       sph_fn=RealSphericalHarmonics(l_max=3, num_harmonics=16),
#       W=f32[16,16,64,64]
#     ),
#     EquivariantConv(
#       radial_fn=GaussianSmearing(centers=f32[16], widths=weak_f32[16]),
#       sph_fn=RealSphericalHarmonics(l_max=3, num_harmonics=16),
#       W=f32[16,16,64,64]
#     ),
#     EquivariantConv(
#       radial_fn=GaussianSmearing(centers=f32[16], widths=weak_f32[16]),
#       sph_fn=RealSphericalHarmonics(l_max=3, num_harmonics=16),
#       W=f32[16,16,64,64]
#     ),
#     EquivariantConv(
#       radial_fn=GaussianSmearing(centers=f32[16], widths=weak_f32[16]),
#       sph_fn=RealSphericalHarmonics(l_max=3, num_harmonics=16),
#       W=f32[16,16,64,64]
#     ),
#     EquivariantConv(
#       radial_fn=GaussianSmearing(centers=f32[16], widths=weak_f32[16]),
#       sph_fn=RealSphericalHarmonics(l_max=3, num_harmonics=16),
#       W=f32[16,16,64,64]
#     )
#   ),
#   w1=f32[64,64],
#   b1=f32[64],
#   w2=f32[64,1],
#   b2=f32[1]
# )

# %%
# Test Model
sample = ds.get(0)
pos      = sample['pos']      # (n_atoms, 3)
z        = sample['z']        # (n_atoms,)
nbr_idx  = sample['nbr_idx']  # (n_atoms, n_nbr)
nbr_dist = sample['nbr_dist'] # (n_atoms, n_nbr)
nbr_mask = sample['nbr_mask'] # (n_atoms, n_nbr)

E_pred = model(pos, z, nbr_idx, nbr_dist, nbr_mask)
print("Predicted energy shape:", E_pred.shape)        # should be ()

F_pred = model.forces(pos, z, nbr_idx, nbr_dist, nbr_mask)
print("Predicted forces shape:", F_pred.shape)        # should be (n_atoms, 3)

print("Any NaNs in energy?:", bool(jnp.isnan(E_pred)))
print("Any Infs in energy?:", bool(jnp.isinf(E_pred)))
print("Any NaNs in forces?:", bool(jnp.isnan(F_pred).any()))
print("Any Infs in forces?:", bool(jnp.isinf(F_pred).any()))
# Out:
# Predicted energy shape: ()
# Predicted forces shape: (15, 3)
# Any NaNs in energy?: False
# Any Infs in energy?: False
# Any NaNs in forces?: False
# Any Infs in forces?: False

# %%
# Pick one convolutional layer (say the first one in your model)
conv = model.convs[0]

# Grab a single frame from your dataset
sample = ds.get(0)
feats    = model.embedding[sample['z']]        # (n_atoms, hidden_feats)
pos      = sample['pos']                       # (n_atoms, 3)
nbr_idx  = sample['nbr_idx']                   # (n_atoms, n_nbr)
nbr_dist = sample['nbr_dist']                  # (n_atoms, n_nbr)
nbr_mask = sample['nbr_mask']                  # (n_atoms, n_nbr)

# Run the conv
out = conv(feats, pos, nbr_idx, nbr_dist, nbr_mask)

print("Input feats shape:", feats.shape)
print("Output feats shape:", out.shape)
print("Any NaNs in output?:", bool(jnp.isnan(out).any()))
# Out:
# Input feats shape: (15, 64)
# Output feats shape: (15, 64)
# Any NaNs in output?: False

# %%
# --- Build train/validation split ---
n_val     = int(flat_config['n_val'])
idx_all   = jnp.arange(len(ds))
train_idx = idx_all[:-n_val]
val_idx   = idx_all[-n_val:]

# --- Precomputed normalization constants (from earlier) ---
# mean_E_pa, std_E_pa, std_F

# Gather all force components across your dataset
F_all = []
for i in range(len(ds)):
    frame = ds.get(i)
    F_all.append(np.array(frame['forces']))   # shape (n_atoms, 3)
F_all = np.stack(F_all)                       # shape (n_frames, n_atoms, 3)
std_F = float(F_all.std())                    # a single scalar
# print("Global force std:", std_F)

# … your train/val split and std_F computation above …
checkpoint_root: str = "/content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models"

# %%
def run_training(
    model,
    dataset,
    train_idx,
    val_idx,
    *,
    learning_rate: float = float(flat_config['learning_rate']),
    force_coeff:   float = float(flat_config['loss_coeffs.forces']),
    batch_size:    int   = int(flat_config['batch_size']),
    num_epochs:    int   = int(flat_config['max_epochs']),
    patience:      int   = int(flat_config['early_stopping_patiences.validation_loss']),
    min_delta:     float = float(flat_config['early_stopping_lower_bounds.LR']),
    print_every:   int   = 1,
    seed:          int   = int(flat_config['seed']),
):
    key = jax.random.PRNGKey(seed)
    os.makedirs(checkpoint_root, exist_ok=True)
    print("In training …")

    # Learning‐rate schedule & optimizer
    steps_per_epoch = max(1, train_idx.shape[0] // batch_size)
    total_steps     = steps_per_epoch * num_epochs
    lr_schedule = optax.cosine_decay_schedule(
        init_value=learning_rate,
        decay_steps=total_steps,
        alpha=0.0,  # decay all the way to zero
    )
    optimizer = optax.chain(
        optax.clip_by_global_norm(1.0),
        optax.adamw(learning_rate=lr_schedule, weight_decay=1e-5)
    )
    opt_state = optimizer.init(eqx.filter(model, eqx.is_array))

    # Metrics containers
    train_e_losses = []
    train_f_losses = []
    val_e_losses   = []
    val_f_losses   = []
    lrs            = []
    step = 0  # will count *batches*

    # Loss fn
    def compute_loss(model, batch):
        # energy
        def single_energy(pos, z, nbr_idx, nbr_dist, nbr_mask):
            return model(pos, z, nbr_idx, nbr_dist, nbr_mask)
        E_pred = jax.vmap(single_energy)(
            batch['pos'], batch['z'],
            batch['nbr_idx'], batch['nbr_dist'], batch['nbr_mask']
        )
        # forces
        def single_force(pos, z, nbr_idx, nbr_dist, nbr_mask):
            return model.forces(pos, z, nbr_idx, nbr_dist, nbr_mask)
        F_pred = jax.vmap(single_force)(
            batch['pos'], batch['z'],
            batch['nbr_idx'], batch['nbr_dist'], batch['nbr_mask']
        )
        # per-atom‐energy MSE (standardized)
        n_atoms    = batch['pos'].shape[1]
        E_pa_pred  = (E_pred / n_atoms - mean_E_pa) / std_E_pa
        E_pa_true  = (batch['energy'] / n_atoms - mean_E_pa) / std_E_pa
        e_loss     = jnp.mean((E_pa_pred - E_pa_true)**2)
        # force MSE (standardized)
        F_s_pred   = F_pred / std_F
        F_s_true   = batch['forces'] / std_F
        f_loss     = jnp.mean((F_s_pred - F_s_true)**2)
        return e_loss + force_coeff * f_loss, (e_loss, f_loss)

    # Single‐step (jit‑compiled)
    @jax.jit
    def train_step(model, opt_state, batch, force_coeff):
        (loss, (e_loss, f_loss)), grads = eqx.filter_value_and_grad(
            compute_loss, has_aux=True
        )(model, batch)
        params = eqx.filter(model, eqx.is_array)
        updates, opt_state = optimizer.update(grads, opt_state, params)
        model = eqx.apply_updates(model, updates)
        return model, opt_state, loss, e_loss, f_loss

    # Early‑stop setup
    # os.makedirs("checkpoint_root", exist_ok=True)
    best_val = float("inf")
    wait     = 0

    # Training loop
    start_all = time.time()
    for epoch in tqdm(range(1, num_epochs + 1), desc="Epochs"):
        t0 = time.time()

        # record current LR
        lrs.append(float(lr_schedule(step)))

        # **inner loop over batches**
        perm = jax.random.permutation(key, train_idx.shape[0])
        for i in range(0, train_idx.shape[0], batch_size):
            batch_idx = train_idx[perm[i : i + batch_size]]
            batch     = dataset.get_batch(batch_idx)
            model, opt_state, loss, e_loss, f_loss = train_step(
                model, opt_state, batch, force_coeff
            )
            # ← **BUMP** the step counter *per batch* so the LR schedule advances
            step += 1

        # Log train metrics
        train_e_losses.append(float(e_loss))
        train_f_losses.append(float(f_loss))

        # Evaluate on validation set
        _, (val_e, val_f) = compute_loss(model, dataset.get_batch(val_idx))
        val_loss = float(val_e + force_coeff * val_f)
        val_e_losses.append(float(val_e))
        val_f_losses.append(float(val_f))

        # Timing & logging
        t1 = time.time()
        if epoch % print_every == 0:
            elapsed = t1 - start_all
            print(
                f"Epoch {epoch}/{num_epochs}  "
                f"time this epoch: {t1-t0:.1f}s  "
                f"elapsed: {elapsed/60:.1f}m  "
                f"train E={e_loss:.4f}, F={f_loss:.4f}  "
                f"val E={val_e:.4f}, F={val_f:.4f}"
            )

        # Early stopping & checkpoint
        if best_val - val_loss > min_delta:
            best_val = val_loss
            wait     = 0
            ckpt = f"{checkpoint_root}/best_epoch{epoch}.eqx"
            eqx.tree_serialise_leaves(ckpt, model)
            print(f" ↳ New best val_loss={best_val:.4f}, saved to {ckpt}")
        else:
            wait += 1
            if wait >= patience:
                print(f"Stopping early after {epoch} epochs (no improvement).")
                break

    # Return everything
    metrics = {
        "train_e": train_e_losses,
        "train_f": train_f_losses,
        "val_e":   val_e_losses,
        "val_f":   val_f_losses,
        "lr":      lrs,
    }
    return model, opt_state, metrics

# %%
# import copy

# # Test using small dataset first
# mini_train = train_idx[:16]
# mini_val   = val_idx[:4]

# # copy the fresh model
# model_mini = copy.deepcopy(model)

# model_mini, _, metrics_mini = run_training(
#     model_mini,
#     ds,
#     mini_train,
#     mini_val,
#     num_epochs=2,          # run just 3 epochs
#     print_every=1,
#     learning_rate=1e-4,    # much lower LR
#     force_coeff=force_coeff,
#     batch_size=8,          # two batches of 8 each
# )

# print("mini train_e:", metrics_mini["train_e"])
# print("mini val_e:  ", metrics_mini["val_e"])

# %%
## HARDCODE Hypoerparameters for final adjustment
learning_rate = 0.001
# n_layers = 8
# hidden = 128
# batch_size = 16
learning_rate = learning_rate
print(f"learning_rate {learning_rate}")
print(f"force_coeff {force_coeff}")
print(f"batch_size {batch_size}")
print(f"num_epochs {num_epochs}")
print(f"seed {seed}")
# Out:
# learning_rate 0.001
# force_coeff 1.0
# batch_size 5
# num_epochs 100000
# seed 123

# %% [markdown]
# Tune Hyperparameters. Override yaml config as per model needs

# %%
# Run training
print_every = 1

model, opt_state, metrics = run_training(
    model,
    ds,
    train_idx,
    val_idx,
    num_epochs=num_epochs,
    print_every= print_every,
    learning_rate=learning_rate,
    force_coeff= 1.0,
)

# After training, serialize the final model
eqx.tree_serialise_leaves(f"{checkpoint_root}/final_model.eqx", model)
print(f"Saved final model to {checkpoint_root}/final_model.eqx")
# Out:
# In training …
# Epochs:   0%|          | 0/100000 [00:00<?, ?it/s]
# Epoch 1/100000  time this epoch: 98.3s  elapsed: 1.6m  train E=0.2570, F=0.9187  val E=0.8542, F=1.0665
#  ↳ New best val_loss=1.9207, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch1.eqx
# Epoch 2/100000  time this epoch: 29.2s  elapsed: 2.2m  train E=0.2854, F=0.9185  val E=0.6266, F=1.0668
#  ↳ New best val_loss=1.6933, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch2.eqx
# Epoch 3/100000  time this epoch: 29.0s  elapsed: 2.7m  train E=0.2911, F=0.9180  val E=0.4825, F=1.0672
#  ↳ New best val_loss=1.5497, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch3.eqx
# Epoch 4/100000  time this epoch: 29.9s  elapsed: 3.3m  train E=0.2786, F=0.9188  val E=0.5065, F=1.0670
# Epoch 5/100000  time this epoch: 29.8s  elapsed: 3.8m  train E=0.2786, F=0.9188  val E=0.5065, F=1.0670
# Epoch 6/100000  time this epoch: 30.3s  elapsed: 4.3m  train E=0.2763, F=0.9188  val E=0.5141, F=1.0670
# Epoch 7/100000  time this epoch: 29.4s  elapsed: 4.8m  train E=0.2763, F=0.9188  val E=0.5141, F=1.0670
# Epoch 8/100000  time this epoch: 30.1s  elapsed: 5.3m  train E=0.2763, F=0.9188  val E=0.5141, F=1.0670
# Epoch 9/100000  time this epoch: 29.6s  elapsed: 5.7m  train E=0.2763, F=0.9188  val E=0.5141, F=1.0670
# Epoch 10/100000  time this epoch: 29.9s  elapsed: 6.2m  train E=0.2763, F=0.9188  val E=0.5141, F=1.0670
# Epoch 11/100000  time this epoch: 29.7s  elapsed: 6.7m  train E=0.2786, F=0.9188  val E=0.5065, F=1.0670
# Epoch 12/100000  time this epoch: 29.0s  elapsed: 7.2m  train E=0.2786, F=0.9188  val E=0.5065, F=1.0670
# Epoch 13/100000  time this epoch: 30.7s  elapsed: 7.7m  train E=0.2786, F=0.9188  val E=0.5065, F=1.0670
# Epoch 14/100000  time this epoch: 30.5s  elapsed: 8.2m  train E=0.2786, F=0.9188  val E=0.5065, F=1.0670
# Epoch 15/100000  time this epoch: 29.0s  elapsed: 8.7m  train E=0.2786, F=0.9188  val E=0.5065, F=1.0670
# Epoch 16/100000  time this epoch: 29.7s  elapsed: 9.2m  train E=0.2786, F=0.9188  val E=0.5065, F=1.0670
# Epoch 17/100000  time this epoch: 30.8s  elapsed: 9.7m  train E=0.2786, F=0.9188  val E=0.5065, F=1.0670
# Epoch 18/100000  time this epoch: 28.7s  elapsed: 10.2m  train E=0.2786, F=0.9188  val E=0.5065, F=1.0670
# Epoch 19/100000  time this epoch: 30.1s  elapsed: 10.7m  train E=0.2786, F=0.9188  val E=0.5065, F=1.0670
# Epoch 20/100000  time this epoch: 28.9s  elapsed: 11.2m  train E=0.2786, F=0.9188  val E=0.5065, F=1.0670
# Epoch 21/100000  time this epoch: 30.6s  elapsed: 11.7m  train E=0.2786, F=0.9188  val E=0.5065, F=1.0670
# Epoch 22/100000  time this epoch: 29.4s  elapsed: 12.2m  train E=0.2786, F=0.9188  val E=0.5065, F=1.0670
# Epoch 23/100000  time this epoch: 30.0s  elapsed: 12.7m  train E=0.2786, F=0.9188  val E=0.5065, F=1.0670
# Epoch 24/100000  time this epoch: 29.2s  elapsed: 13.2m  train E=0.2786, F=0.9188  val E=0.5065, F=1.0670
# Epoch 25/100000  time this epoch: 30.8s  elapsed: 13.7m  train E=0.2786, F=0.9188  val E=0.5065, F=1.0670
# Epoch 26/100000  time this epoch: 29.3s  elapsed: 14.2m  train E=0.2786, F=0.9188  val E=0.5065, F=1.0670
# Epoch 27/100000  time this epoch: 31.4s  elapsed: 14.7m  train E=0.2793, F=0.9188  val E=0.5065, F=1.0670
# Epoch 28/100000  time this epoch: 29.4s  elapsed: 15.2m  train E=0.2793, F=0.9188  val E=0.5040, F=1.0670
# Epoch 29/100000  time this epoch: 29.8s  elapsed: 15.7m  train E=0.2793, F=0.9188  val E=0.5040, F=1.0670
# Epoch 30/100000  time this epoch: 31.2s  elapsed: 16.2m  train E=0.2793, F=0.9188  val E=0.5040, F=1.0670
# Epoch 31/100000  time this epoch: 29.4s  elapsed: 16.7m  train E=0.2793, F=0.9188  val E=0.5040, F=1.0670
# Epoch 32/100000  time this epoch: 31.7s  elapsed: 17.2m  train E=0.2793, F=0.9188  val E=0.5040, F=1.0670
# Epoch 33/100000  time this epoch: 29.3s  elapsed: 17.7m  train E=0.2793, F=0.9188  val E=0.5040, F=1.0670
# Epoch 34/100000  time this epoch: 29.9s  elapsed: 18.2m  train E=0.2793, F=0.9188  val E=0.5040, F=1.0670
# Epoch 35/100000  time this epoch: 31.4s  elapsed: 18.7m  train E=0.2793, F=0.9188  val E=0.5040, F=1.0670
# Epoch 36/100000  time this epoch: 29.3s  elapsed: 19.2m  train E=0.2793, F=0.9188  val E=0.5040, F=1.0670
# Epoch 37/100000  time this epoch: 29.5s  elapsed: 19.7m  train E=0.2793, F=0.9188  val E=0.5040, F=1.0670
# Epoch 38/100000  time this epoch: 31.9s  elapsed: 20.3m  train E=0.3343, F=0.9186  val E=0.4962, F=1.0665
# Epoch 39/100000  time this epoch: 29.7s  elapsed: 20.7m  train E=0.3267, F=0.9200  val E=0.5112, F=1.0672
# Epoch 40/100000  time this epoch: 29.8s  elapsed: 21.2m  train E=0.2803, F=0.9188  val E=0.5104, F=1.0669
# Epoch 41/100000  time this epoch: 31.7s  elapsed: 21.8m  train E=0.2826, F=0.9188  val E=0.5077, F=1.0669
# Epoch 42/100000  time this epoch: 29.6s  elapsed: 22.3m  train E=0.2689, F=0.9188  val E=0.5463, F=1.0670
# Epoch 43/100000  time this epoch: 29.9s  elapsed: 22.8m  train E=0.2758, F=0.9191  val E=0.5573, F=1.0684
# Epoch 44/100000  time this epoch: 29.6s  elapsed: 23.3m  train E=0.2810, F=0.9190  val E=0.5444, F=1.0668
# Epoch 45/100000  time this epoch: 31.7s  elapsed: 23.8m  train E=0.3038, F=0.9187  val E=0.4785, F=1.0668
#  ↳ New best val_loss=1.5452, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch45.eqx
# Epoch 46/100000  time this epoch: 29.6s  elapsed: 24.3m  train E=0.2894, F=0.9185  val E=0.4897, F=1.0669
# Epoch 47/100000  time this epoch: 30.0s  elapsed: 24.8m  train E=0.3074, F=0.9189  val E=0.5082, F=1.0667
# Epoch 48/100000  time this epoch: 32.1s  elapsed: 25.3m  train E=0.3056, F=0.9180  val E=0.4957, F=1.0668
# Epoch 49/100000  time this epoch: 30.5s  elapsed: 25.8m  train E=0.3021, F=0.9187  val E=0.5213, F=1.0670
# Epoch 50/100000  time this epoch: 30.0s  elapsed: 26.3m  train E=0.3123, F=0.9178  val E=0.5003, F=1.0670
# Epoch 51/100000  time this epoch: 30.1s  elapsed: 26.8m  train E=0.2923, F=0.9186  val E=0.5417, F=1.0671
# Epoch 52/100000  time this epoch: 32.9s  elapsed: 27.4m  train E=0.2785, F=0.9183  val E=0.5255, F=1.0670
# Epoch 53/100000  time this epoch: 29.8s  elapsed: 27.9m  train E=0.2730, F=0.9179  val E=0.5496, F=1.0667
# Epoch 54/100000  time this epoch: 30.1s  elapsed: 28.4m  train E=0.2904, F=0.9178  val E=0.5166, F=1.0671
# Epoch 55/100000  time this epoch: 30.1s  elapsed: 28.9m  train E=0.2736, F=0.9177  val E=0.5331, F=1.0665
# Epoch 56/100000  time this epoch: 32.9s  elapsed: 29.4m  train E=0.2686, F=0.9182  val E=0.5782, F=1.0671
# Epoch 57/100000  time this epoch: 30.2s  elapsed: 29.9m  train E=0.2879, F=0.9177  val E=0.5447, F=1.0665
# Epoch 58/100000  time this epoch: 30.1s  elapsed: 30.4m  train E=0.2841, F=0.9172  val E=0.5393, F=1.0667
# Epoch 59/100000  time this epoch: 30.2s  elapsed: 30.9m  train E=0.3048, F=0.9130  val E=0.5763, F=1.0667
# Epoch 60/100000  time this epoch: 33.4s  elapsed: 31.5m  train E=0.3023, F=0.9083  val E=0.5109, F=1.0631
# Epoch 61/100000  time this epoch: 30.2s  elapsed: 32.0m  train E=0.4337, F=0.8553  val E=0.5045, F=1.0570
# Epoch 62/100000  time this epoch: 30.3s  elapsed: 32.5m  train E=0.3831, F=0.7866  val E=0.5842, F=1.0506
# Epoch 63/100000  time this epoch: 30.5s  elapsed: 33.0m  train E=0.3366, F=0.7958  val E=0.5786, F=1.0295
# Epoch 64/100000  time this epoch: 29.6s  elapsed: 33.5m  train E=0.3208, F=0.7190  val E=0.4982, F=1.0229
#  ↳ New best val_loss=1.5211, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch64.eqx
# Epoch 65/100000  time this epoch: 31.4s  elapsed: 34.0m  train E=0.3753, F=0.6784  val E=0.7016, F=0.9710
# Epoch 66/100000  time this epoch: 28.3s  elapsed: 34.5m  train E=0.4650, F=0.6444  val E=0.4311, F=0.9289
#  ↳ New best val_loss=1.3601, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch66.eqx
# Epoch 67/100000  time this epoch: 30.0s  elapsed: 35.0m  train E=0.3248, F=0.6461  val E=0.6294, F=0.9356
# Epoch 68/100000  time this epoch: 29.3s  elapsed: 35.5m  train E=0.3250, F=0.6437  val E=0.3962, F=0.9181
#  ↳ New best val_loss=1.3142, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch68.eqx
# Epoch 69/100000  time this epoch: 29.0s  elapsed: 36.0m  train E=0.2796, F=0.5884  val E=0.5567, F=0.8985
# Epoch 70/100000  time this epoch: 31.8s  elapsed: 36.5m  train E=0.3703, F=0.5597  val E=0.5032, F=0.8930
# Epoch 71/100000  time this epoch: 28.6s  elapsed: 37.0m  train E=0.3953, F=0.5496  val E=0.4721, F=0.8704
# Epoch 72/100000  time this epoch: 29.0s  elapsed: 37.5m  train E=0.3053, F=0.5467  val E=0.4477, F=0.8679
# Epoch 73/100000  time this epoch: 28.9s  elapsed: 38.0m  train E=0.2760, F=0.5205  val E=0.5493, F=0.8307
# Epoch 74/100000  time this epoch: 31.4s  elapsed: 38.5m  train E=0.3256, F=0.5240  val E=0.5255, F=0.8329
# Epoch 75/100000  time this epoch: 29.2s  elapsed: 39.0m  train E=0.3923, F=0.5167  val E=0.5471, F=0.8268
# Epoch 76/100000  time this epoch: 28.5s  elapsed: 39.5m  train E=0.2807, F=0.4982  val E=0.6095, F=0.8585
# Epoch 77/100000  time this epoch: 28.3s  elapsed: 39.9m  train E=0.3282, F=0.4866  val E=0.5000, F=0.8179
# Epoch 78/100000  time this epoch: 29.1s  elapsed: 40.4m  train E=0.3067, F=0.4658  val E=0.4367, F=0.8201
#  ↳ New best val_loss=1.2567, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch78.eqx
# Epoch 79/100000  time this epoch: 32.0s  elapsed: 41.0m  train E=0.3273, F=0.4590  val E=0.4630, F=0.7775
#  ↳ New best val_loss=1.2404, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch79.eqx
# Epoch 80/100000  time this epoch: 28.9s  elapsed: 41.4m  train E=0.4061, F=0.4565  val E=0.4066, F=0.7934
#  ↳ New best val_loss=1.1999, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch80.eqx
# Epoch 81/100000  time this epoch: 28.9s  elapsed: 41.9m  train E=0.4936, F=0.4620  val E=0.4357, F=0.7964
# Epoch 82/100000  time this epoch: 29.9s  elapsed: 42.4m  train E=0.3133, F=0.4550  val E=0.4268, F=0.7780
# Epoch 83/100000  time this epoch: 31.3s  elapsed: 42.9m  train E=0.2688, F=0.4427  val E=0.4736, F=0.7940
# Epoch 84/100000  time this epoch: 28.8s  elapsed: 43.4m  train E=0.3630, F=0.4260  val E=0.5079, F=0.7908
# Epoch 85/100000  time this epoch: 29.2s  elapsed: 43.9m  train E=0.4459, F=0.4326  val E=0.5314, F=0.7609
# Epoch 86/100000  time this epoch: 29.0s  elapsed: 44.4m  train E=0.3155, F=0.4217  val E=0.4540, F=0.7615
# Epoch 87/100000  time this epoch: 28.5s  elapsed: 44.9m  train E=0.4647, F=0.4209  val E=0.4179, F=0.7757
#  ↳ New best val_loss=1.1936, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch87.eqx
# Epoch 88/100000  time this epoch: 31.4s  elapsed: 45.4m  train E=0.3209, F=0.4254  val E=0.4807, F=0.7781
# Epoch 89/100000  time this epoch: 28.6s  elapsed: 45.9m  train E=0.2853, F=0.4094  val E=0.4315, F=0.7733
# Epoch 90/100000  time this epoch: 28.8s  elapsed: 46.4m  train E=0.3486, F=0.4298  val E=0.4202, F=0.7946
# Epoch 91/100000  time this epoch: 29.3s  elapsed: 46.8m  train E=0.2938, F=0.4019  val E=0.4381, F=0.7830
# Epoch 92/100000  time this epoch: 32.4s  elapsed: 47.4m  train E=0.2764, F=0.3885  val E=0.4929, F=0.7748
# Epoch 93/100000  time this epoch: 29.0s  elapsed: 47.9m  train E=0.3449, F=0.3985  val E=0.4261, F=0.7839
# Epoch 94/100000  time this epoch: 29.0s  elapsed: 48.4m  train E=0.4383, F=0.3974  val E=0.4145, F=0.7830
# Epoch 95/100000  time this epoch: 28.8s  elapsed: 48.8m  train E=0.3921, F=0.3808  val E=0.3797, F=0.7584
#  ↳ New best val_loss=1.1382, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch95.eqx
# Epoch 96/100000  time this epoch: 29.0s  elapsed: 49.3m  train E=0.3322, F=0.3778  val E=0.4140, F=0.7514
# Epoch 97/100000  time this epoch: 31.9s  elapsed: 49.8m  train E=0.3144, F=0.3782  val E=0.4366, F=0.7397
# Epoch 98/100000  time this epoch: 29.3s  elapsed: 50.3m  train E=0.3156, F=0.3680  val E=0.5076, F=0.7445
# Epoch 99/100000  time this epoch: 28.7s  elapsed: 50.8m  train E=0.4884, F=0.3524  val E=0.4409, F=0.7458
# Epoch 100/100000  time this epoch: 28.7s  elapsed: 51.3m  train E=0.4794, F=0.3624  val E=0.3921, F=0.7210
#  ↳ New best val_loss=1.1131, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch100.eqx
# Epoch 101/100000  time this epoch: 29.3s  elapsed: 51.8m  train E=0.3133, F=0.3432  val E=0.4263, F=0.7053
# Epoch 102/100000  time this epoch: 32.2s  elapsed: 52.3m  train E=0.3352, F=0.3055  val E=0.4794, F=0.7002
# Epoch 103/100000  time this epoch: 29.1s  elapsed: 52.8m  train E=0.4221, F=0.3069  val E=0.4417, F=0.7237
# Epoch 104/100000  time this epoch: 28.8s  elapsed: 53.3m  train E=0.2936, F=0.2836  val E=0.4589, F=0.7311
# Epoch 105/100000  time this epoch: 29.0s  elapsed: 53.8m  train E=0.3396, F=0.2456  val E=0.4097, F=0.7369
# Epoch 106/100000  time this epoch: 31.7s  elapsed: 54.3m  train E=0.3778, F=0.2532  val E=0.4425, F=0.7228
# Epoch 107/100000  time this epoch: 29.0s  elapsed: 54.8m  train E=0.2971, F=0.2442  val E=0.4488, F=0.6857
# Epoch 108/100000  time this epoch: 29.0s  elapsed: 55.3m  train E=0.3292, F=0.2421  val E=0.4612, F=0.6892
# Epoch 109/100000  time this epoch: 29.3s  elapsed: 55.7m  train E=0.3923, F=0.2189  val E=0.3857, F=0.6897
#  ↳ New best val_loss=1.0754, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch109.eqx
# Epoch 110/100000  time this epoch: 28.8s  elapsed: 56.2m  train E=0.3531, F=0.2345  val E=0.3622, F=0.6539
#  ↳ New best val_loss=1.0160, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch110.eqx
# Epoch 111/100000  time this epoch: 32.3s  elapsed: 56.8m  train E=0.2772, F=0.2454  val E=0.3697, F=0.6809
# Epoch 112/100000  time this epoch: 29.0s  elapsed: 57.3m  train E=0.4770, F=0.2396  val E=0.4302, F=0.6905
# Epoch 113/100000  time this epoch: 28.7s  elapsed: 57.7m  train E=0.4128, F=0.2371  val E=0.4057, F=0.7090
# Epoch 114/100000  time this epoch: 29.1s  elapsed: 58.2m  train E=0.6079, F=0.1963  val E=0.5109, F=0.6270
# Epoch 115/100000  time this epoch: 32.2s  elapsed: 58.8m  train E=0.4996, F=0.2286  val E=0.4713, F=0.6356
# Epoch 116/100000  time this epoch: 28.9s  elapsed: 59.2m  train E=0.3256, F=0.2042  val E=0.5310, F=0.6554
# Epoch 117/100000  time this epoch: 29.2s  elapsed: 59.7m  train E=0.3819, F=0.2461  val E=0.4516, F=0.6859
# Epoch 118/100000  time this epoch: 28.6s  elapsed: 60.2m  train E=0.4113, F=0.2263  val E=0.5214, F=0.6390
# Epoch 119/100000  time this epoch: 29.1s  elapsed: 60.7m  train E=0.2982, F=0.2054  val E=0.4923, F=0.6598
# Epoch 120/100000  time this epoch: 32.1s  elapsed: 61.2m  train E=0.3552, F=0.2116  val E=0.4838, F=0.6698
# Epoch 121/100000  time this epoch: 29.3s  elapsed: 61.7m  train E=0.3875, F=0.2186  val E=0.4046, F=0.6403
# Epoch 122/100000  time this epoch: 29.9s  elapsed: 62.2m  train E=0.3627, F=0.1772  val E=0.4533, F=0.6317
# Epoch 123/100000  time this epoch: 29.5s  elapsed: 62.7m  train E=0.4236, F=0.1877  val E=0.3513, F=0.6481
#  ↳ New best val_loss=0.9994, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch123.eqx
# Epoch 124/100000  time this epoch: 32.5s  elapsed: 63.2m  train E=0.4270, F=0.1961  val E=0.4529, F=0.6279
# Epoch 125/100000  time this epoch: 29.4s  elapsed: 63.7m  train E=0.3181, F=0.1670  val E=0.4377, F=0.6633
# Epoch 126/100000  time this epoch: 28.6s  elapsed: 64.2m  train E=0.4163, F=0.1873  val E=0.4057, F=0.6557
# Epoch 127/100000  time this epoch: 29.8s  elapsed: 64.7m  train E=0.3062, F=0.1871  val E=0.5208, F=0.6850
# Epoch 128/100000  time this epoch: 28.7s  elapsed: 65.2m  train E=0.4718, F=0.1860  val E=0.4114, F=0.6558
# Epoch 129/100000  time this epoch: 32.1s  elapsed: 65.7m  train E=0.3336, F=0.1793  val E=0.3892, F=0.6806
# Epoch 130/100000  time this epoch: 28.6s  elapsed: 66.2m  train E=0.3454, F=0.1704  val E=0.4583, F=0.6622
# Epoch 131/100000  time this epoch: 28.8s  elapsed: 66.7m  train E=0.5512, F=0.1786  val E=0.4201, F=0.6777
# Epoch 132/100000  time this epoch: 29.1s  elapsed: 67.2m  train E=0.3710, F=0.1799  val E=0.4791, F=0.6336
# Epoch 133/100000  time this epoch: 29.0s  elapsed: 67.6m  train E=0.4819, F=0.1738  val E=0.4583, F=0.6747
# Epoch 134/100000  time this epoch: 32.1s  elapsed: 68.2m  train E=0.3178, F=0.2363  val E=0.3682, F=0.6739
# Epoch 135/100000  time this epoch: 29.0s  elapsed: 68.7m  train E=0.4130, F=0.1826  val E=0.5039, F=0.6446
# Epoch 136/100000  time this epoch: 28.8s  elapsed: 69.1m  train E=0.4753, F=0.1865  val E=0.3981, F=0.6303
# Epoch 137/100000  time this epoch: 29.2s  elapsed: 69.6m  train E=0.3713, F=0.1567  val E=0.4317, F=0.6335
# Epoch 138/100000  time this epoch: 32.5s  elapsed: 70.2m  train E=0.4404, F=0.1912  val E=0.4746, F=0.6450
# Epoch 139/100000  time this epoch: 29.5s  elapsed: 70.7m  train E=0.3660, F=0.1931  val E=0.5812, F=0.6293
# Epoch 140/100000  time this epoch: 29.4s  elapsed: 71.2m  train E=0.3211, F=0.1691  val E=0.3998, F=0.6339
# Epoch 141/100000  time this epoch: 29.4s  elapsed: 71.6m  train E=0.3899, F=0.1638  val E=0.4464, F=0.6542
# Epoch 142/100000  time this epoch: 29.2s  elapsed: 72.1m  train E=0.3157, F=0.1537  val E=0.4195, F=0.6404
# Epoch 143/100000  time this epoch: 33.1s  elapsed: 72.7m  train E=0.4592, F=0.2047  val E=0.3740, F=0.6703
# Epoch 144/100000  time this epoch: 29.6s  elapsed: 73.2m  train E=0.4145, F=0.1956  val E=0.3685, F=0.6293
#  ↳ New best val_loss=0.9978, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch144.eqx
# Epoch 145/100000  time this epoch: 28.8s  elapsed: 73.7m  train E=0.2853, F=0.1557  val E=0.3817, F=0.6221
# Epoch 146/100000  time this epoch: 28.8s  elapsed: 74.1m  train E=0.3625, F=0.1840  val E=0.4206, F=0.6483
# Epoch 147/100000  time this epoch: 32.9s  elapsed: 74.7m  train E=0.4262, F=0.1641  val E=0.4123, F=0.6451
# Epoch 148/100000  time this epoch: 28.9s  elapsed: 75.2m  train E=0.2921, F=0.1372  val E=0.4103, F=0.6120
# Epoch 149/100000  time this epoch: 29.0s  elapsed: 75.6m  train E=0.3017, F=0.1504  val E=0.4316, F=0.6381
# Epoch 150/100000  time this epoch: 28.5s  elapsed: 76.1m  train E=0.3078, F=0.1434  val E=0.4581, F=0.6252
# Epoch 151/100000  time this epoch: 29.0s  elapsed: 76.6m  train E=0.2873, F=0.1514  val E=0.4406, F=0.6593
# Epoch 152/100000  time this epoch: 31.9s  elapsed: 77.1m  train E=0.5250, F=0.1460  val E=0.4341, F=0.6289
# Epoch 153/100000  time this epoch: 29.0s  elapsed: 77.6m  train E=0.3171, F=0.1518  val E=0.4031, F=0.6122
# Epoch 154/100000  time this epoch: 29.5s  elapsed: 78.1m  train E=0.4087, F=0.1509  val E=0.4128, F=0.6201
# Epoch 155/100000  time this epoch: 28.9s  elapsed: 78.6m  train E=0.3089, F=0.1527  val E=0.3936, F=0.5894
#  ↳ New best val_loss=0.9829, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch155.eqx
# Epoch 156/100000  time this epoch: 29.0s  elapsed: 79.1m  train E=0.3013, F=0.1526  val E=0.3977, F=0.6473
# Epoch 157/100000  time this epoch: 32.2s  elapsed: 79.6m  train E=0.3391, F=0.1611  val E=0.4498, F=0.6125
# Epoch 158/100000  time this epoch: 29.1s  elapsed: 80.1m  train E=0.4205, F=0.1462  val E=0.4159, F=0.6305
# Epoch 159/100000  time this epoch: 28.6s  elapsed: 80.6m  train E=0.4092, F=0.1428  val E=0.4543, F=0.6025
# Epoch 160/100000  time this epoch: 29.8s  elapsed: 81.1m  train E=0.3216, F=0.1546  val E=0.3449, F=0.6226
#  ↳ New best val_loss=0.9675, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch160.eqx
# Epoch 161/100000  time this epoch: 32.4s  elapsed: 81.6m  train E=0.3124, F=0.1354  val E=0.3809, F=0.6171
# Epoch 162/100000  time this epoch: 29.1s  elapsed: 82.1m  train E=0.2904, F=0.1397  val E=0.3894, F=0.6193
# Epoch 163/100000  time this epoch: 29.2s  elapsed: 82.6m  train E=0.2781, F=0.1392  val E=0.3248, F=0.6017
#  ↳ New best val_loss=0.9266, saved to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/best_epoch163.eqx
# Epoch 164/100000  time this epoch: 29.3s  elapsed: 83.1m  train E=0.2832, F=0.1302  val E=0.3959, F=0.6360
# Epoch 165/100000  time this epoch: 28.8s  elapsed: 83.6m  train E=0.3938, F=0.1449  val E=0.4207, F=0.6292
# Epoch 166/100000  time this epoch: 33.2s  elapsed: 84.1m  train E=0.4228, F=0.1376  val E=0.4190, F=0.6084
# Epoch 167/100000  time this epoch: 29.3s  elapsed: 84.6m  train E=0.3451, F=0.1597  val E=0.4003, F=0.5883
# Epoch 168/100000  time this epoch: 29.1s  elapsed: 85.1m  train E=0.3445, F=0.1353  val E=0.4261, F=0.6308
# Epoch 169/100000  time this epoch: 29.4s  elapsed: 85.6m  train E=0.3998, F=0.1377  val E=0.4713, F=0.6255
# Epoch 170/100000  time this epoch: 32.4s  elapsed: 86.1m  train E=0.3117, F=0.1335  val E=0.3800, F=0.5988
# Epoch 171/100000  time this epoch: 29.0s  elapsed: 86.6m  train E=0.3337, F=0.1473  val E=0.3934, F=0.6313
# Epoch 172/100000  time this epoch: 29.1s  elapsed: 87.1m  train E=0.5361, F=0.1419  val E=0.5283, F=0.6446
# Epoch 173/100000  time this epoch: 29.3s  elapsed: 87.6m  train E=0.3858, F=0.1435  val E=0.4234, F=0.6560
# Epoch 174/100000  time this epoch: 29.4s  elapsed: 88.1m  train E=0.3064, F=0.1419  val E=0.4485, F=0.6476
# Epoch 175/100000  time this epoch: 33.2s  elapsed: 88.6m  train E=0.5243, F=0.1388  val E=0.4262, F=0.6241
# Epoch 176/100000  time this epoch: 29.2s  elapsed: 89.1m  train E=0.3381, F=0.1310  val E=0.4235, F=0.6068
# Epoch 177/100000  time this epoch: 29.2s  elapsed: 89.6m  train E=0.5244, F=0.1516  val E=0.4556, F=0.6231
# Epoch 178/100000  time this epoch: 28.6s  elapsed: 90.1m  train E=0.4051, F=0.1298  val E=0.3701, F=0.6136
# Epoch 179/100000  time this epoch: 32.3s  elapsed: 90.6m  train E=0.4476, F=0.1296  val E=0.4267, F=0.6214
# Epoch 180/100000  time this epoch: 29.5s  elapsed: 91.1m  train E=0.3933, F=0.1327  val E=0.4408, F=0.6254
# Epoch 181/100000  time this epoch: 28.9s  elapsed: 91.6m  train E=0.3835, F=0.1341  val E=0.4282, F=0.6293
# Epoch 182/100000  time this epoch: 29.5s  elapsed: 92.1m  train E=0.3605, F=0.1249  val E=0.4273, F=0.6329
# Epoch 183/100000  time this epoch: 28.8s  elapsed: 92.5m  train E=0.4237, F=0.1380  val E=0.4314, F=0.6247
# Epoch 184/100000  time this epoch: 33.0s  elapsed: 93.1m  train E=0.3048, F=0.1592  val E=0.4180, F=0.6350
# Epoch 185/100000  time this epoch: 29.7s  elapsed: 93.6m  train E=0.3414, F=0.1305  val E=0.4162, F=0.6234
# Epoch 186/100000  time this epoch: 28.8s  elapsed: 94.1m  train E=0.3607, F=0.1540  val E=0.3850, F=0.6493
# Epoch 187/100000  time this epoch: 28.9s  elapsed: 94.6m  train E=0.3513, F=0.1262  val E=0.4186, F=0.6202
# Epoch 188/100000  time this epoch: 32.9s  elapsed: 95.1m  train E=0.3804, F=0.1256  val E=0.4508, F=0.5915
# Epoch 189/100000  time this epoch: 29.3s  elapsed: 95.6m  train E=0.2947, F=0.1328  val E=0.4801, F=0.6608
# Epoch 190/100000  time this epoch: 28.9s  elapsed: 96.1m  train E=0.3495, F=0.1307  val E=0.4272, F=0.6201
# Epoch 191/100000  time this epoch: 28.7s  elapsed: 96.6m  train E=0.4553, F=0.1283  val E=0.3957, F=0.6140
# Epoch 192/100000  time this epoch: 29.8s  elapsed: 97.0m  train E=0.3954, F=0.1314  val E=0.4452, F=0.6355
# Epoch 193/100000  time this epoch: 33.0s  elapsed: 97.6m  train E=0.3904, F=0.1214  val E=0.4301, F=0.5880
# Epoch 194/100000  time this epoch: 29.1s  elapsed: 98.1m  train E=0.3597, F=0.1325  val E=0.4171, F=0.6294
# Epoch 195/100000  time this epoch: 29.2s  elapsed: 98.6m  train E=0.3963, F=0.1368  val E=0.3943, F=0.6095
# Epoch 196/100000  time this epoch: 29.6s  elapsed: 99.1m  train E=0.3073, F=0.1307  val E=0.5088, F=0.6000
# Epoch 197/100000  time this epoch: 29.1s  elapsed: 99.5m  train E=0.2893, F=0.1194  val E=0.4716, F=0.6133
# Epoch 198/100000  time this epoch: 32.7s  elapsed: 100.1m  train E=0.3668, F=0.1394  val E=0.4684, F=0.6128
# Epoch 199/100000  time this epoch: 29.5s  elapsed: 100.6m  train E=0.5007, F=0.1318  val E=0.5115, F=0.6176
# Epoch 200/100000  time this epoch: 29.8s  elapsed: 101.1m  train E=0.2967, F=0.1215  val E=0.5724, F=0.6842
# Epoch 201/100000  time this epoch: 28.9s  elapsed: 101.6m  train E=0.5183, F=0.1282  val E=0.5530, F=0.7181
# Epoch 202/100000  time this epoch: 32.4s  elapsed: 102.1m  train E=0.2912, F=0.1241  val E=0.4771, F=0.6094
# Epoch 203/100000  time this epoch: 29.1s  elapsed: 102.6m  train E=0.3251, F=0.1391  val E=0.4555, F=0.6261
# Epoch 204/100000  time this epoch: 29.1s  elapsed: 103.1m  train E=0.5493, F=0.1324  val E=0.4524, F=0.6148
# Epoch 205/100000  time this epoch: 29.2s  elapsed: 103.6m  train E=0.4626, F=0.1599  val E=0.5269, F=0.6099
# Epoch 206/100000  time this epoch: 29.2s  elapsed: 104.0m  train E=0.3674, F=0.1668  val E=0.4528, F=0.6026
# Epoch 207/100000  time this epoch: 33.2s  elapsed: 104.6m  train E=0.3811, F=0.1302  val E=0.4274, F=0.5877
# Epoch 208/100000  time this epoch: 29.2s  elapsed: 105.1m  train E=0.3368, F=0.1296  val E=0.5032, F=0.6237
# Epoch 209/100000  time this epoch: 29.1s  elapsed: 105.6m  train E=0.2945, F=0.1141  val E=0.4731, F=0.5727
# Epoch 210/100000  time this epoch: 28.8s  elapsed: 106.1m  train E=0.3609, F=0.1130  val E=0.4891, F=0.5985
# Epoch 211/100000  time this epoch: 33.7s  elapsed: 106.6m  train E=0.2931, F=0.1264  val E=0.4609, F=0.6000
# Epoch 212/100000  time this epoch: 29.5s  elapsed: 107.1m  train E=0.4445, F=0.1312  val E=0.5012, F=0.5929
# Epoch 213/100000  time this epoch: 29.6s  elapsed: 107.6m  train E=0.4342, F=0.1511  val E=0.5607, F=0.6168
# Stopping early after 213 epochs (no improvement).
# Saved final model to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/trained_custom_models/final_model.eqx

# %%
# Ensure `metrics` is in scope (returned by your updated run_training)
epochs = list(range(1, len(metrics['train_e']) + 1))

# 1) Energy Loss Plot
plt.figure()
plt.plot(epochs, metrics['train_e'], label='Train E_loss')
plt.plot(epochs, metrics['val_e'],   label='Val E_loss')
plt.xlabel('Epoch')
plt.ylabel('Standardized Energy Loss')
plt.title('Energy Loss vs. Epoch')
plt.legend()
plt.show()

# 2) Force Loss Plot
plt.figure()
plt.plot(epochs, metrics['train_f'], label='Train F_loss')
plt.plot(epochs, metrics['val_f'],   label='Val F_loss')
plt.xlabel('Epoch')
plt.ylabel('Standardized Force Loss')
plt.title('Force Loss vs. Epoch')
plt.legend()
plt.show()

# 3) Learning Rate Schedule
plt.figure()
plt.plot(epochs, metrics['lr'], label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('Learning Rate')
plt.title('Learning Rate Schedule')
plt.legend()
plt.show()

# %%
import os
import pandas as pd

n_epochs = len(metrics['train_e'])
df = pd.DataFrame({
    'epoch':                      list(range(1, n_epochs+1)),
    'train/loss/energy_mae':      metrics['train_e'],
    'train/loss/forces_mse':      metrics['train_f'],
    'val/loss/energy_mae':        metrics['val_e'],
    'val/loss/forces_mse':        metrics['val_f'],
    'train/metric/learning_rate': metrics['lr'],
     'val/metric/learning_rate':  metrics['lr'],
})

# point here instead of flat_config paths
outdir = "/content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/results"
os.makedirs(outdir, exist_ok=True)

metrics_csv = os.path.join(outdir, "metrics.csv")
df.to_csv(metrics_csv, index=False)
print(f"Wrote metrics to {metrics_csv}")
# Out:
# Wrote metrics to /content/drive/MyDrive/Colab_Notebooks/Nequip_reimplement/train/results/metrics.csv

# %%
plt.rcParams.update({'font.size': 10})

# Define colors_dict here
colors_dict = {
    'energy_mae': 'blue',
    'forces_mse': 'red',
    'learning_rate': 'green',
    # Add more mappings as needed
}

def get_metrics(df, group="train", type="loss"):
    if group == "train":
        cols = [c for c in df.columns if all(x in c for x in ["train", type])]
    else:
        cols = [c for c in df.columns if all(x in c for x in [group, type])]
    keep = ["epoch"] + cols
    sub = df[keep].dropna(subset=cols)
    renamed = {c: c.split("/")[-1] for c in cols}
    return sub.rename(columns=renamed), list(renamed.values())

def plot_metric_in_ax(ax, df, group="train", type="loss"):
    df_sub, names = get_metrics(df, group, type)
    lines, labels = [], []
    for name in names:
        color = colors_dict.get(name, None)
        line, = ax.plot(df_sub["epoch"], df_sub[name], color=color)
        lines.append(line)
        labels.append(name)
    ax.set_yscale("log")
    ax.set_xlabel("Epoch")
    ax.set_title(f"{group.title()} {type.title()}")
    ax.legend(lines, labels)

def plot_metrics(df):
    fig, axes = plt.subplots(2, 2, figsize=(14,8))
    plot_metric_in_ax(axes[0,0], df, "train", "loss")
    plot_metric_in_ax(axes[0,1], df, "train", "metric")
    plot_metric_in_ax(axes[1,0], df, "val",   "loss")
    plot_metric_in_ax(axes[1,1], df, "val",   "metric")
    plt.tight_layout()
    plt.show()

# load and plot
metrics_df = pd.read_csv(metrics_csv)
plot_metrics(metrics_df)

# %%
n_epochs = len(metrics['train_e'])
epochs   = range(1, n_epochs + 1)

plt.figure(figsize=(6,4))
# plot energy losses
plt.plot(epochs, metrics['train_e'], label='Train E_loss', linestyle='-')
plt.plot(epochs, metrics['val_e'],   label='Val   E_loss', linestyle='--')
# plot force losses
plt.plot(epochs, metrics['train_f'], label='Train F_loss', linestyle='-')
plt.plot(epochs, metrics['val_f'],   label='Val   F_loss', linestyle='--')

plt.xlabel('Epoch')
plt.ylabel('Standardized Loss')
plt.title('Training & Validation Losses')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()
